# %%
#@title Select station coordinates (N+ S- W- and E+) and n nearest points
lat_station = 41.296 #@param {type:"number"}
lon_station = 2.078 #@param {type:"number"}
n_nearest =  2#@param {type:"integer"}
forecast_D = 1 #@param ["0", "1", "2", "3"] {type:"raw"}
initial_day_YYYYMMDD = "20200101" #@param {type:"raw"}
final_day_YYYYMMDD = "20201231" #@param {type:"raw"}
spatial_resolution = "12Km" #@param ["4Km", "12Km", "36Km"] {allow-input: true}

# %%
pip install simplekml

# %%
import simplekml
from urllib.request import urlretrieve
import xarray as xr
import numpy as np
import pandas as pd
from math import radians, cos, sin, asin, sqrt
from datetime import timedelta

def haversine(lon1, lat1, lon2, lat2):
       lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
       dlon, dlat = lon2 - lon1 ,lat2 - lat1
       a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
       km = 2 * asin(sqrt(a))*6367
       return km
#directory drive
root=""

# select url from 4km, 12km, 1.3Km and 36km in order to get the nearest points. Not real forecast !!!
#url1="http://mandeo.meteogalicia.es/thredds/ncss/modelos/WRF_HIST/d05/2020/11/wrf_arw_det_history_d05_20211101_0000.nc4?var=mod&disableLLSubset=on&disableProjSubset=on&horizStride=1&time_start=2020-11-01T01%3A00%3A00Z&time_end=2020-11-01T01%3A00%3A00Z&timeStride=1&addLatLon=true&accept=netcdf"
url4="http://mandeo.meteogalicia.es/thredds/ncss/modelos/WRF_HIST/d03/2020/11/wrf_arw_det_history_d03_20201101_0000.nc4?var=mod&disableLLSubset=on&disableProjSubset=on&horizStride=1&time_start=2020-11-01T01%3A00%3A00Z&time_end=2020-11-01T01%3A00%3A00Z&timeStride=1&addLatLon=true&accept=netcdf"
url12="http://mandeo.meteogalicia.es/thredds/ncss/modelos/WRF_HIST/d02/2016/09/wrf_arw_det_history_d02_20160927_0000.nc4?var=mod&disableLLSubset=on&disableProjSubset=on&horizStride=1&time_start=2016-09-27T01%3A00%3A00Z&time_end=2016-09-27T01%3A00%3A00Z&timeStride=1&addLatLon=true&accept=netcdf"
url36="http://mandeo.meteogalicia.es/thredds/ncss/modelos/WRF_HIST/d01/2018/10/wrf_arw_det_history_d01_20181031_0000.nc4?var=mod&disableLLSubset=on&disableProjSubset=on&horizStride=1&time_start=2018-10-31T01%3A00%3A00Z&time_end=2018-10-31T01%3A00%3A00Z&timeStride=1&addLatLon=true&accept=netcdf"
resolution={"4Km":url4,"12Km":url12,"36Km":url36}
resol_tag={"4Km":"d03","12Km":"d02","36Km":"d01"}
df=xr.open_dataset(urlretrieve(resolution[spatial_resolution])[0],).to_dataframe()
df_n=pd.DataFrame(df[["lat","lon","mod"]].values,columns=df[["lat","lon","mod"]].columns)

#add station coordinates
df_n["lat_st"],df_n["lon_st"]=lat_station,lon_station

#find the distances from the meteorological model to the station
for index, row in df_n.iterrows():
       df_n.loc[index, 'distance'] = round(haversine(row['lon'], row['lat'], row['lon_st'], row['lat_st']),2)

#select n nearest points to the station.
df_r=df_n.sort_values(by=["distance"]).head(n_nearest)

# KML with all the distances to the station
#df_n["distance"]=df_n["distance"].astype(str)
#kml = simplekml.Kml()
#df_n.apply(lambda X: kml.newpoint(name=X["distance"], coords=[( X["lon"],X["lat"])]) ,axis=1)
#kml.save("full_"+spatial_resolution+".kml")

# KML with nearest n points
df_r["distance"]=df_r["distance"].astype(str)
kmlr = simplekml.Kml()
df_r.apply(lambda X: kmlr.newpoint(name=X["distance"], coords=[( X["lon"],X["lat"])]) ,axis=1)
kmlr.newpoint(name="STATION",coords=[(lon_station,lat_station)])
kmlr.save(root+"lat"+str(lat_station)+"lon"+str(lon_station)+"p"+str(n_nearest)+"R"+str(spatial_resolution)+".kml")

#save nearest points as csv file
df_r.set_index(np.arange(0,n_nearest)).drop(["mod"],axis=1).to_csv(root+"distan_"+"lat"+str(lat_station)+"lon"+str(lon_station)+"p"+str(n_nearest)+"R"+str(spatial_resolution)+".csv")

#get the meteorological model
df_sum=pd.DataFrame()
for a_day in pd.date_range(start=str(initial_day_YYYYMMDD), end=str(final_day_YYYYMMDD)):
  print("analysis date:",a_day)
  head=a_day.strftime("http://mandeo.meteogalicia.es/thredds/ncss/modelos/WRF_HIST/"+resol_tag[spatial_resolution]+"/%Y/%m/wrf_arw_det_history_"+resol_tag[spatial_resolution]+"_%Y%m%d_0000.nc4?")
  f_day=(a_day+timedelta(days=forecast_D)).strftime("%Y-%m-%d")
  var="var=dir&var=snow_prec&var=snowlevel&var=mod&var=wind_gust&var=mslp&var=temp&var=rh&var=visibility&var=lhflx&var=lwflx&var=conv_prec&var=prec&var=swflx&var=shflx&var=cape&var=cin&var=cfh&var=cfl&var=cfm&var=cft&var=HGT500&var=HGT850&var=T500&var=T850"
  tail="&time_start="+f_day+"T00%3A00%3A00Z&time_end="+f_day+"T23%3A00%3A00Z&accept=csv"
  try:
     dffinal=pd.DataFrame()
     for coor in list(zip(df_r["lat"].astype(str),df_r["lon"].astype(str),np.arange(0,n_nearest).astype(str))):
        dffinal=pd.concat([dffinal,pd.read_csv(head+var+"&latitude="+coor[0]+"&longitude="+coor[1]+tail,).add_suffix(coor[2])],axis=1)

     #filter all columns with lat lon and date
     dffinal=dffinal.filter(regex='^(?!(lat|lon|date).*?)')

     #remove column string between brakets
     new_col=[c.split("[")[0]+c.split("]")[-1] for c in dffinal.columns]
     for col in zip(dffinal.columns,new_col):
       dffinal=dffinal.rename(columns = {col[0]:col[1]})

     #add time
     if forecast_D==0:
       dffinal["time"]=pd.date_range(f_day,periods=24, freq='H')[1:]
     else:
       dffinal["time"]=pd.date_range(f_day,periods=24, freq='H')
     df_sum=pd.concat([df_sum,dffinal.set_index("time")])

  except:
     print(a_day,"failed")

#time index to column
df_sum.reset_index(inplace=True)

#save csv file
df_sum.to_csv(root+"lat"+str(lat_station)+"lon"+str(lon_station)+"p"+str(n_nearest)+"R"+str(spatial_resolution)+"D"+str(forecast_D)+".csv")
# Out:
# analysis date: 2020-01-01 00:00:00
# analysis date: 2020-01-02 00:00:00
# analysis date: 2020-01-03 00:00:00
# analysis date: 2020-01-04 00:00:00
# analysis date: 2020-01-05 00:00:00
# analysis date: 2020-01-06 00:00:00
# analysis date: 2020-01-07 00:00:00
# analysis date: 2020-01-08 00:00:00
# analysis date: 2020-01-09 00:00:00
# analysis date: 2020-01-10 00:00:00
# analysis date: 2020-01-11 00:00:00
# analysis date: 2020-01-12 00:00:00
# analysis date: 2020-01-13 00:00:00
# analysis date: 2020-01-14 00:00:00
# analysis date: 2020-01-15 00:00:00
# analysis date: 2020-01-16 00:00:00
# analysis date: 2020-01-17 00:00:00
# analysis date: 2020-01-18 00:00:00
# analysis date: 2020-01-19 00:00:00
# analysis date: 2020-01-20 00:00:00
# analysis date: 2020-01-21 00:00:00
# analysis date: 2020-01-22 00:00:00
# analysis date: 2020-01-23 00:00:00
# analysis date: 2020-01-24 00:00:00
# analysis date: 2020-01-25 00:00:00
# analysis date: 2020-01-26 00:00:00
# analysis date: 2020-01-27 00:00:00
# analysis date: 2020-01-28 00:00:00
# analysis date: 2020-01-29 00:00:00
# analysis date: 2020-01-30 00:00:00
# analysis date: 2020-01-31 00:00:00
# analysis date: 2020-02-01 00:00:00
# analysis date: 2020-02-02 00:00:00
# analysis date: 2020-02-03 00:00:00
# analysis date: 2020-02-04 00:00:00
# analysis date: 2020-02-05 00:00:00
# analysis date: 2020-02-06 00:00:00
# analysis date: 2020-02-07 00:00:00
# analysis date: 2020-02-08 00:00:00
# analysis date: 2020-02-09 00:00:00
# analysis date: 2020-02-10 00:00:00
# analysis date: 2020-02-11 00:00:00
# analysis date: 2020-02-12 00:00:00
# analysis date: 2020-02-13 00:00:00
# analysis date: 2020-02-14 00:00:00
# analysis date: 2020-02-15 00:00:00
# analysis date: 2020-02-16 00:00:00
# analysis date: 2020-02-17 00:00:00
# analysis date: 2020-02-18 00:00:00
# analysis date: 2020-02-19 00:00:00
# analysis date: 2020-02-20 00:00:00
# analysis date: 2020-02-21 00:00:00
# analysis date: 2020-02-22 00:00:00
# analysis date: 2020-02-23 00:00:00
# analysis date: 2020-02-24 00:00:00
# analysis date: 2020-02-25 00:00:00
# analysis date: 2020-02-26 00:00:00
# analysis date: 2020-02-27 00:00:00
# analysis date: 2020-02-28 00:00:00
# analysis date: 2020-02-29 00:00:00
# analysis date: 2020-03-01 00:00:00
# analysis date: 2020-03-02 00:00:00
# analysis date: 2020-03-03 00:00:00
# analysis date: 2020-03-04 00:00:00
# analysis date: 2020-03-05 00:00:00
# analysis date: 2020-03-06 00:00:00
# analysis date: 2020-03-07 00:00:00
# analysis date: 2020-03-08 00:00:00
# analysis date: 2020-03-09 00:00:00
# analysis date: 2020-03-10 00:00:00
# analysis date: 2020-03-11 00:00:00
# analysis date: 2020-03-12 00:00:00
# analysis date: 2020-03-13 00:00:00
# analysis date: 2020-03-14 00:00:00
# analysis date: 2020-03-15 00:00:00
# analysis date: 2020-03-16 00:00:00
# analysis date: 2020-03-17 00:00:00
# analysis date: 2020-03-18 00:00:00
# analysis date: 2020-03-19 00:00:00
# analysis date: 2020-03-20 00:00:00
# analysis date: 2020-03-21 00:00:00
# analysis date: 2020-03-22 00:00:00
# analysis date: 2020-03-23 00:00:00
# analysis date: 2020-03-24 00:00:00
# analysis date: 2020-03-25 00:00:00
# analysis date: 2020-03-26 00:00:00
# analysis date: 2020-03-27 00:00:00
# analysis date: 2020-03-28 00:00:00
# analysis date: 2020-03-29 00:00:00
# analysis date: 2020-03-30 00:00:00
# analysis date: 2020-03-31 00:00:00
# analysis date: 2020-04-01 00:00:00
# analysis date: 2020-04-02 00:00:00
# analysis date: 2020-04-03 00:00:00
# analysis date: 2020-04-04 00:00:00
# analysis date: 2020-04-05 00:00:00
# analysis date: 2020-04-06 00:00:00
# analysis date: 2020-04-07 00:00:00
# analysis date: 2020-04-08 00:00:00
# analysis date: 2020-04-09 00:00:00
# analysis date: 2020-04-10 00:00:00
# analysis date: 2020-04-11 00:00:00
# analysis date: 2020-04-12 00:00:00
# analysis date: 2020-04-13 00:00:00
# analysis date: 2020-04-14 00:00:00
# analysis date: 2020-04-15 00:00:00
# analysis date: 2020-04-16 00:00:00
# analysis date: 2020-04-17 00:00:00
# analysis date: 2020-04-18 00:00:00
# analysis date: 2020-04-19 00:00:00
# analysis date: 2020-04-20 00:00:00
# analysis date: 2020-04-21 00:00:00
# analysis date: 2020-04-22 00:00:00
# analysis date: 2020-04-23 00:00:00
# analysis date: 2020-04-24 00:00:00
# analysis date: 2020-04-25 00:00:00
# analysis date: 2020-04-26 00:00:00
# analysis date: 2020-04-27 00:00:00
# analysis date: 2020-04-28 00:00:00
# analysis date: 2020-04-29 00:00:00
# analysis date: 2020-04-30 00:00:00
# analysis date: 2020-05-01 00:00:00
# analysis date: 2020-05-02 00:00:00
# analysis date: 2020-05-03 00:00:00
# analysis date: 2020-05-04 00:00:00
# analysis date: 2020-05-05 00:00:00
# analysis date: 2020-05-06 00:00:00
# analysis date: 2020-05-07 00:00:00
# analysis date: 2020-05-08 00:00:00
# analysis date: 2020-05-09 00:00:00
# analysis date: 2020-05-10 00:00:00
# analysis date: 2020-05-11 00:00:00
# analysis date: 2020-05-12 00:00:00
# analysis date: 2020-05-13 00:00:00
# analysis date: 2020-05-14 00:00:00
# analysis date: 2020-05-15 00:00:00
# analysis date: 2020-05-16 00:00:00
# analysis date: 2020-05-17 00:00:00
# analysis date: 2020-05-18 00:00:00
# analysis date: 2020-05-19 00:00:00
# analysis date: 2020-05-20 00:00:00
# analysis date: 2020-05-21 00:00:00
# analysis date: 2020-05-22 00:00:00
# analysis date: 2020-05-23 00:00:00
# analysis date: 2020-05-24 00:00:00
# analysis date: 2020-05-25 00:00:00
# analysis date: 2020-05-26 00:00:00
# analysis date: 2020-05-27 00:00:00
# analysis date: 2020-05-28 00:00:00
# analysis date: 2020-05-29 00:00:00
# analysis date: 2020-05-30 00:00:00
# analysis date: 2020-05-31 00:00:00
# analysis date: 2020-06-01 00:00:00
# analysis date: 2020-06-02 00:00:00
# analysis date: 2020-06-03 00:00:00
# analysis date: 2020-06-04 00:00:00
# analysis date: 2020-06-05 00:00:00
# analysis date: 2020-06-06 00:00:00
# analysis date: 2020-06-07 00:00:00
# analysis date: 2020-06-08 00:00:00
# analysis date: 2020-06-09 00:00:00
# analysis date: 2020-06-10 00:00:00
# 2020-06-10 00:00:00 failed
# analysis date: 2020-06-11 00:00:00
# analysis date: 2020-06-12 00:00:00
# analysis date: 2020-06-13 00:00:00
# analysis date: 2020-06-14 00:00:00
# analysis date: 2020-06-15 00:00:00
# analysis date: 2020-06-16 00:00:00
# analysis date: 2020-06-17 00:00:00
# analysis date: 2020-06-18 00:00:00
# analysis date: 2020-06-19 00:00:00
# analysis date: 2020-06-20 00:00:00
# analysis date: 2020-06-21 00:00:00
# analysis date: 2020-06-22 00:00:00
# analysis date: 2020-06-23 00:00:00
# analysis date: 2020-06-24 00:00:00
# analysis date: 2020-06-25 00:00:00
# analysis date: 2020-06-26 00:00:00
# analysis date: 2020-06-27 00:00:00
# analysis date: 2020-06-28 00:00:00
# analysis date: 2020-06-29 00:00:00
# analysis date: 2020-06-30 00:00:00
# analysis date: 2020-07-01 00:00:00
# analysis date: 2020-07-02 00:00:00
# analysis date: 2020-07-03 00:00:00
# analysis date: 2020-07-04 00:00:00
# analysis date: 2020-07-05 00:00:00
# analysis date: 2020-07-06 00:00:00
# analysis date: 2020-07-07 00:00:00
# analysis date: 2020-07-08 00:00:00
# analysis date: 2020-07-09 00:00:00
# analysis date: 2020-07-10 00:00:00
# analysis date: 2020-07-11 00:00:00
# analysis date: 2020-07-12 00:00:00
# analysis date: 2020-07-13 00:00:00
# analysis date: 2020-07-14 00:00:00
# analysis date: 2020-07-15 00:00:00
# analysis date: 2020-07-16 00:00:00
# analysis date: 2020-07-17 00:00:00
# analysis date: 2020-07-18 00:00:00
# analysis date: 2020-07-19 00:00:00
# analysis date: 2020-07-20 00:00:00
# analysis date: 2020-07-21 00:00:00
# analysis date: 2020-07-22 00:00:00
# analysis date: 2020-07-23 00:00:00
# analysis date: 2020-07-24 00:00:00
# analysis date: 2020-07-25 00:00:00
# analysis date: 2020-07-26 00:00:00
# analysis date: 2020-07-27 00:00:00
# analysis date: 2020-07-28 00:00:00
# analysis date: 2020-07-29 00:00:00
# analysis date: 2020-07-30 00:00:00
# analysis date: 2020-07-31 00:00:00
# analysis date: 2020-08-01 00:00:00
# analysis date: 2020-08-02 00:00:00
# analysis date: 2020-08-03 00:00:00
# analysis date: 2020-08-04 00:00:00
# analysis date: 2020-08-05 00:00:00
# analysis date: 2020-08-06 00:00:00
# analysis date: 2020-08-07 00:00:00
# analysis date: 2020-08-08 00:00:00
# analysis date: 2020-08-09 00:00:00
# analysis date: 2020-08-10 00:00:00
# analysis date: 2020-08-11 00:00:00
# analysis date: 2020-08-12 00:00:00
# analysis date: 2020-08-13 00:00:00
# analysis date: 2020-08-14 00:00:00
# analysis date: 2020-08-15 00:00:00
# analysis date: 2020-08-16 00:00:00
# analysis date: 2020-08-17 00:00:00
# analysis date: 2020-08-18 00:00:00
# analysis date: 2020-08-19 00:00:00
# analysis date: 2020-08-20 00:00:00
# analysis date: 2020-08-21 00:00:00
# analysis date: 2020-08-22 00:00:00
# analysis date: 2020-08-23 00:00:00
# analysis date: 2020-08-24 00:00:00
# analysis date: 2020-08-25 00:00:00
# analysis date: 2020-08-26 00:00:00
# analysis date: 2020-08-27 00:00:00
# analysis date: 2020-08-28 00:00:00
# analysis date: 2020-08-29 00:00:00
# analysis date: 2020-08-30 00:00:00
# analysis date: 2020-08-31 00:00:00
# analysis date: 2020-09-01 00:00:00
# analysis date: 2020-09-02 00:00:00
# analysis date: 2020-09-03 00:00:00
# analysis date: 2020-09-04 00:00:00
# analysis date: 2020-09-05 00:00:00
# analysis date: 2020-09-06 00:00:00
# analysis date: 2020-09-07 00:00:00
# analysis date: 2020-09-08 00:00:00
# analysis date: 2020-09-09 00:00:00
# analysis date: 2020-09-10 00:00:00
# analysis date: 2020-09-11 00:00:00
# analysis date: 2020-09-12 00:00:00
# analysis date: 2020-09-13 00:00:00
# analysis date: 2020-09-14 00:00:00
# analysis date: 2020-09-15 00:00:00
# analysis date: 2020-09-16 00:00:00
# analysis date: 2020-09-17 00:00:00
# analysis date: 2020-09-18 00:00:00
# analysis date: 2020-09-19 00:00:00
# analysis date: 2020-09-20 00:00:00
# analysis date: 2020-09-21 00:00:00
# analysis date: 2020-09-22 00:00:00
# analysis date: 2020-09-23 00:00:00
# analysis date: 2020-09-24 00:00:00
# analysis date: 2020-09-25 00:00:00
# analysis date: 2020-09-26 00:00:00
# analysis date: 2020-09-27 00:00:00
# analysis date: 2020-09-28 00:00:00
# analysis date: 2020-09-29 00:00:00
# analysis date: 2020-09-30 00:00:00
# analysis date: 2020-10-01 00:00:00
# analysis date: 2020-10-02 00:00:00
# analysis date: 2020-10-03 00:00:00
# analysis date: 2020-10-04 00:00:00
# analysis date: 2020-10-05 00:00:00
# analysis date: 2020-10-06 00:00:00
# analysis date: 2020-10-07 00:00:00
# analysis date: 2020-10-08 00:00:00
# analysis date: 2020-10-09 00:00:00
# analysis date: 2020-10-10 00:00:00
# analysis date: 2020-10-11 00:00:00
# analysis date: 2020-10-12 00:00:00
# analysis date: 2020-10-13 00:00:00
# analysis date: 2020-10-14 00:00:00
# analysis date: 2020-10-15 00:00:00
# analysis date: 2020-10-16 00:00:00
# analysis date: 2020-10-17 00:00:00
# analysis date: 2020-10-18 00:00:00
# analysis date: 2020-10-19 00:00:00
# analysis date: 2020-10-20 00:00:00
# analysis date: 2020-10-21 00:00:00
# analysis date: 2020-10-22 00:00:00
# analysis date: 2020-10-23 00:00:00
# analysis date: 2020-10-24 00:00:00
# analysis date: 2020-10-25 00:00:00
# analysis date: 2020-10-26 00:00:00
# analysis date: 2020-10-27 00:00:00
# analysis date: 2020-10-28 00:00:00
# analysis date: 2020-10-29 00:00:00
# analysis date: 2020-10-30 00:00:00
# analysis date: 2020-10-31 00:00:00
# analysis date: 2020-11-01 00:00:00
# analysis date: 2020-11-02 00:00:00
# analysis date: 2020-11-03 00:00:00
# analysis date: 2020-11-04 00:00:00
# analysis date: 2020-11-05 00:00:00
# analysis date: 2020-11-06 00:00:00
# analysis date: 2020-11-07 00:00:00
# analysis date: 2020-11-08 00:00:00
# analysis date: 2020-11-09 00:00:00
# analysis date: 2020-11-10 00:00:00
# analysis date: 2020-11-11 00:00:00
# analysis date: 2020-11-12 00:00:00
# analysis date: 2020-11-13 00:00:00
# analysis date: 2020-11-14 00:00:00
# analysis date: 2020-11-15 00:00:00
# analysis date: 2020-11-16 00:00:00
# analysis date: 2020-11-17 00:00:00
# analysis date: 2020-11-18 00:00:00
# analysis date: 2020-11-19 00:00:00
# analysis date: 2020-11-20 00:00:00
# analysis date: 2020-11-21 00:00:00
# analysis date: 2020-11-22 00:00:00
# analysis date: 2020-11-23 00:00:00
# analysis date: 2020-11-24 00:00:00
# analysis date: 2020-11-25 00:00:00
# analysis date: 2020-11-26 00:00:00
# analysis date: 2020-11-27 00:00:00
# analysis date: 2020-11-28 00:00:00
# analysis date: 2020-11-29 00:00:00
# analysis date: 2020-11-30 00:00:00
# analysis date: 2020-12-01 00:00:00
# analysis date: 2020-12-02 00:00:00
# analysis date: 2020-12-03 00:00:00
# analysis date: 2020-12-04 00:00:00
# analysis date: 2020-12-05 00:00:00
# analysis date: 2020-12-06 00:00:00
# analysis date: 2020-12-07 00:00:00
# analysis date: 2020-12-08 00:00:00
# analysis date: 2020-12-09 00:00:00
# analysis date: 2020-12-10 00:00:00
# analysis date: 2020-12-11 00:00:00
# analysis date: 2020-12-12 00:00:00
# analysis date: 2020-12-13 00:00:00
# analysis date: 2020-12-14 00:00:00
# analysis date: 2020-12-15 00:00:00
# analysis date: 2020-12-16 00:00:00
# analysis date: 2020-12-17 00:00:00
# analysis date: 2020-12-18 00:00:00
# analysis date: 2020-12-19 00:00:00
# analysis date: 2020-12-20 00:00:00
# analysis date: 2020-12-21 00:00:00
# analysis date: 2020-12-22 00:00:00
# analysis date: 2020-12-23 00:00:00
# analysis date: 2020-12-24 00:00:00
# analysis date: 2020-12-25 00:00:00
# analysis date: 2020-12-26 00:00:00
# analysis date: 2020-12-27 00:00:00
# analysis date: 2020-12-28 00:00:00
# analysis date: 2020-12-29 00:00:00
# analysis date: 2020-12-30 00:00:00
# analysis date: 2020-12-31 00:00:00
