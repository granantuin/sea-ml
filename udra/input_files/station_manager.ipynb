# %%
import pandas as pd


df = pd.read_csv("/content/resultadoCSV_Columnas (30).csv",)
df =df.rename(columns={"Instante lectura":"time","Refacho a 10m":"gust_coron"})
df['time'] = pd.to_datetime(df['time'])
df = df.set_index("time")
df = df*0.277778
df
# Out:
#                      gust_coron
# time
# 2022-01-01 00:10:00    9.861119
# 2022-01-01 00:20:00   10.916675
# 2022-01-01 00:30:00   12.388899
# 2022-01-01 00:40:00   11.666676
# 2022-01-01 00:50:00   11.722232
# ...                         ...
# 2022-12-30 23:20:00   18.916682
# 2022-12-30 23:30:00   19.222238
# 2022-12-30 23:40:00   17.666681
# 2022-12-30 23:50:00   17.777792
# 2022-12-31 00:00:00   15.805568
#
# [52416 rows x 1 columns]

# %%
df1 = pd.read_csv("/content/resultadoCSV_Columnas (31).csv",)
df1 =df1.rename(columns={"Instante lectura":"time","Refacho a 10m":"gust_coron"})
df1['time'] = pd.to_datetime(df1['time'])
df1 = df1.set_index("time")
df1 = df1*0.277778
df1
# Out:
#                      gust_coron
# time
# 2023-01-01 00:10:00    5.888894
# 2023-01-01 00:20:00    7.000006
# 2023-01-01 00:30:00    6.611116
# 2023-01-01 00:40:00    6.138894
# 2023-01-01 00:50:00    5.250004
# ...                         ...
# 2023-12-30 23:20:00    9.111118
# 2023-12-30 23:30:00    8.944452
# 2023-12-30 23:40:00   10.055564
# 2023-12-30 23:50:00    8.666674
# 2023-12-31 00:00:00    9.722230
#
# [52416 rows x 1 columns]

# %%
df_gust = pd.concat([df,df1])
df_gust
# Out:
#                      gust_coron
# time
# 2022-01-01 00:10:00    9.861119
# 2022-01-01 00:20:00   10.916675
# 2022-01-01 00:30:00   12.388899
# 2022-01-01 00:40:00   11.666676
# 2022-01-01 00:50:00   11.722232
# ...                         ...
# 2023-12-30 23:20:00    9.111118
# 2023-12-30 23:30:00    8.944452
# 2023-12-30 23:40:00   10.055564
# 2023-12-30 23:50:00    8.666674
# 2023-12-31 00:00:00    9.722230
#
# [104832 rows x 1 columns]

# %%
df = pd.read_csv("/content/resultadoCSV_Columnas (28).csv",)
df =df.rename(columns={"Instante lectura":"time","Velocidade do vento a 10m":"spd_coron"})
df['time'] = pd.to_datetime(df['time'])
df = df.set_index("time")
df = df*0.277778
df
# Out:
#                      spd_coron
# time
# 2022-01-01 00:10:00   5.166671
# 2022-01-01 00:20:00   6.750005
# 2022-01-01 00:30:00   7.222228
# 2022-01-01 00:40:00   7.055561
# 2022-01-01 00:50:00   6.111116
# ...                        ...
# 2022-12-30 23:20:00  11.194453
# 2022-12-30 23:30:00  11.861121
# 2022-12-30 23:40:00  10.194453
# 2022-12-30 23:50:00  10.833342
# 2022-12-31 00:00:00   9.944452
#
# [52416 rows x 1 columns]

# %%
df1 = pd.read_csv("/content/resultadoCSV_Columnas (29).csv",)
df1 =df1.rename(columns={"Instante lectura":"time","Velocidade do vento a 10m":"spd_coron"})
df1['time'] = pd.to_datetime(df1['time'])
df1 = df1.set_index("time")
df1 = df1*0.277778
df1
# Out:
#                      spd_coron
# time
# 2023-01-01 00:10:00   3.694447
# 2023-01-01 00:20:00   4.000003
# 2023-01-01 00:30:00   4.055559
# 2023-01-01 00:40:00   3.861114
# 2023-01-01 00:50:00   2.833336
# ...                        ...
# 2023-12-30 23:20:00   6.166672
# 2023-12-30 23:30:00   6.944450
# 2023-12-30 23:40:00   6.916672
# 2023-12-30 23:50:00   6.500005
# 2023-12-31 00:00:00   6.750005
#
# [52416 rows x 1 columns]

# %%
df_spd = pd.concat([df,df1])
df_spd
# Out:
#                      spd_coron
# time
# 2022-01-01 00:10:00   5.166671
# 2022-01-01 00:20:00   6.750005
# 2022-01-01 00:30:00   7.222228
# 2022-01-01 00:40:00   7.055561
# 2022-01-01 00:50:00   6.111116
# ...                        ...
# 2023-12-30 23:20:00   6.166672
# 2023-12-30 23:30:00   6.944450
# 2023-12-30 23:40:00   6.916672
# 2023-12-30 23:50:00   6.500005
# 2023-12-31 00:00:00   6.750005
#
# [104832 rows x 1 columns]

# %%
df = pd.read_csv("/content/resultadoCSV_Columnas (32).csv",)
df =df.rename(columns={"Instante lectura":"time","Direcci?n do vento a 10m":"dir_coron"})
df['time'] = pd.to_datetime(df['time'])
df = df.set_index("time")
df
# Out:
#                      dir_coron
# time
# 2022-01-01 00:10:00      183.0
# 2022-01-01 00:20:00      183.0
# 2022-01-01 00:30:00      181.0
# 2022-01-01 00:40:00      178.0
# 2022-01-01 00:50:00      187.0
# ...                        ...
# 2022-12-30 23:20:00      200.0
# 2022-12-30 23:30:00      200.0
# 2022-12-30 23:40:00      201.0
# 2022-12-30 23:50:00      204.0
# 2022-12-31 00:00:00      204.0
#
# [52416 rows x 1 columns]

# %%
df1 = pd.read_csv("/content/resultadoCSV_Columnas (33).csv",)
df1 =df1.rename(columns={"Instante lectura":"time","Direcci?n do vento a 10m":"dir_coron"})
df1['time'] = pd.to_datetime(df1['time'])
df1 = df1.set_index("time")
df1
# Out:
#                      dir_coron
# time
# 2023-01-01 00:10:00      159.0
# 2023-01-01 00:20:00      160.0
# 2023-01-01 00:30:00      162.0
# 2023-01-01 00:40:00      165.0
# 2023-01-01 00:50:00      164.0
# ...                        ...
# 2023-12-30 23:20:00      239.0
# 2023-12-30 23:30:00      234.0
# 2023-12-30 23:40:00      228.0
# 2023-12-30 23:50:00      227.0
# 2023-12-31 00:00:00      227.0
#
# [52416 rows x 1 columns]

# %%
df_dir = pd.concat([df,df1])
df_dir
# Out:
#                      dir_coron
# time
# 2022-01-01 00:10:00      183.0
# 2022-01-01 00:20:00      183.0
# 2022-01-01 00:30:00      181.0
# 2022-01-01 00:40:00      178.0
# 2022-01-01 00:50:00      187.0
# ...                        ...
# 2023-12-30 23:20:00      239.0
# 2023-12-30 23:30:00      234.0
# 2023-12-30 23:40:00      228.0
# 2023-12-30 23:50:00      227.0
# 2023-12-31 00:00:00      227.0
#
# [104832 rows x 1 columns]

# %%
df_final= pd.concat([df_dir,df_spd,df_gust], axis=1).dropna()
df_final.describe()
# Out:
#            dir_coron      spd_coron     gust_coron
# count  104832.000000  104832.000000  104832.000000
# mean      141.522455       4.602584       6.462221
# std        96.453956       3.161638       4.231597
# min         0.000000       0.000000       0.000000
# 25%        48.000000       1.916668       2.861113
# 50%       148.000000       4.138892       5.805560
# 75%       219.000000       6.888894       9.500008
# max       359.000000      18.527793      34.694472

# %%
df_final
# Out:
#                      dir_coron  spd_coron  gust_coron
# time
# 2022-01-01 00:10:00      183.0   5.166671    9.861119
# 2022-01-01 00:20:00      183.0   6.750005   10.916675
# 2022-01-01 00:30:00      181.0   7.222228   12.388899
# 2022-01-01 00:40:00      178.0   7.055561   11.666676
# 2022-01-01 00:50:00      187.0   6.111116   11.722232
# ...                        ...        ...         ...
# 2023-12-30 23:20:00      239.0   6.166672    9.111118
# 2023-12-30 23:30:00      234.0   6.944450    8.944452
# 2023-12-30 23:40:00      228.0   6.916672   10.055564
# 2023-12-30 23:50:00      227.0   6.500005    8.666674
# 2023-12-31 00:00:00      227.0   6.750005    9.722230
#
# [104832 rows x 3 columns]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 104832 entries, 2022-01-01 00:10:00 to 2023-12-31 00:00:00
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   dir_coron   104832 non-null  float64
#  1   spd_coron   104832 non-null  float64
#  2   gust_coron  104832 non-null  float64
# dtypes: float64(3)
# memory usage: 3.2 MB

# %%
df_final.sample(40).plot
# Out:
#                      dir_coron  spd_coron  gust_coron
# time
# 2023-03-13 15:10:00      242.0   8.722229   13.027788
# 2022-11-26 23:30:00      159.0   2.138891    3.166669
# 2022-07-01 18:00:00      254.0   2.555558    4.027781
# 2022-08-20 04:30:00       48.0   8.527785   11.500009
# 2022-11-23 01:00:00      250.0  10.027786   14.277789
# 2023-10-23 11:30:00      262.0   3.333336    4.055559
# 2022-04-08 08:50:00      215.0  11.638898   16.388902
# 2023-02-19 05:10:00       95.0   1.444446    2.138891
# 2022-08-31 00:10:00      348.0   0.555556    1.138890
# 2023-09-20 08:00:00      203.0   3.361114    5.972227
# 2023-04-24 19:30:00      217.0   2.611113    3.722225
# 2022-09-07 03:00:00      197.0   3.138891    6.222227
# 2023-12-14 17:30:00       53.0   4.638893    5.444449
# 2023-03-24 12:00:00      252.0   6.861117    9.000007
# 2023-01-30 04:10:00       61.0   2.555558    4.194448
# 2023-12-13 14:20:00      314.0   2.722224    3.916670
# ...

# %%
df_final.to_csv("/content/drive/MyDrive/Colab Notebooks/Pontevedra_Ria/coron/input_files/coron.csv")

# %%
df_coron = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Pontevedra_Ria/coron/input_files/coron.csv",parse_dates=["time"]).set_index("time")
df_coron.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 104832 entries, 2022-01-01 00:10:00 to 2023-12-31 00:00:00
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   dir_coron   104832 non-null  float64
#  1   spd_coron   104832 non-null  float64
#  2   gust_coron  104832 non-null  float64
# dtypes: float64(3)
# memory usage: 3.2 MB

# %%
duplicated_indices = df_udr.index.duplicated()
df_udr = df_udr[~duplicated_indices]
df_udr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 104820 entries, 2022-01-01 00:10:00 to 2023-12-31 00:00:00
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   dir_ons   104820 non-null  float64
#  1   spd_ons   104820 non-null  float64
#  2   gust_ons  104820 non-null  float64
# dtypes: float64(3)
# memory usage: 3.2 MB

# %%
df_mar = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Pontevedra_Ria/marin/input_files/marin.csv",parse_dates=["time"]).set_index("time")
df_mar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 104826 entries, 2022-01-01 00:10:00 to 2023-12-31 00:00:00
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   dir_mar   104826 non-null  float64
#  1   spd_mar   104826 non-null  float64
#  2   gust_mar  104826 non-null  float64
# dtypes: float64(3)
# memory usage: 3.2 MB

# %%
duplicated_indices = df_mar.index.duplicated()
df_mar = df_mar[~duplicated_indices]
df_mar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 104814 entries, 2022-01-01 00:10:00 to 2023-12-31 00:00:00
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   dir_mar   104814 non-null  float64
#  1   spd_mar   104814 non-null  float64
#  2   gust_mar  104814 non-null  float64
# dtypes: float64(3)
# memory usage: 3.2 MB

# %%
df_pon= pd.concat([df_mar,df_udr],axis=1).dropna()
df_pon.to_csv("/content/drive/MyDrive/Colab Notebooks/Pontevedra_Ria/marin/input_files/pontevedra.csv")

# %%
df_pon = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Pontevedra_Ria/marin/input_files/pontevedra.csv",parse_dates=["time"]).set_index("time")

# %%
df_pon.columns
# Out:
# Index(['dir_mar', 'spd_mar', 'gust_mar', 'dir_udr', 'spd_udr', 'gust_udr'], dtype='object')

# %%
df_pon[["dir_mar","dir_udr"]].sample(100).plot()
# Out:
# <Axes: xlabel='time'>

# %%
df_pon.describe()
# Out:
#              dir_mar        spd_mar       gust_mar        dir_udr  \
# count  104814.000000  104814.000000  104814.000000  104814.000000
# mean      156.105100       2.735187       4.739836     150.298596
# std       101.757924       2.136095       3.512118     105.410859
# min         0.000000       0.000000       0.000000       0.000000
# 25%        48.000000       1.060000       2.000000      48.000000
# 50%       186.000000       2.220000       3.890000     172.000000
# 75%       232.000000       3.920000       6.560000     213.000000
# max       359.000000      16.720000      27.830000     359.000000
#
#              spd_udr       gust_udr
# count  104814.000000  104814.000000
# mean        4.510057       6.359905
# std         3.517903       4.488996
# min         0.000000       0.000000
# 25%         2.000002       3.111114
# 50%         3.444447       5.083337
# 75%         6.055560       8.416673
# max        23.861130      34.472250
