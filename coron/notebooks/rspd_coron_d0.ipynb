# %% [markdown]
# **get model coordinates**

# %%
import plotly.express as px
import pandas as pd
import numpy as np

coor = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Coron/met_ model/distan_lat42.58lon-8.8046p3R4Km.csv")
px.set_mapbox_access_token("pk.eyJ1IjoiZ3JhbmFudHVpbiIsImEiOiJja3B4dGU4OTkwMTFmMm9ycnNhMjJvaGJqIn0.VWzx_PkD9A5cSUVsn_ijCA")
px.scatter_mapbox(coor, hover_data=['distance'],lat='lat', lon='lon',color='distance', title="nearest points",
                           color_continuous_scale=px.colors.cyclical.IceFire,)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="43084d2f-4155-42a9-bc4d-7f4b955cd3fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("43084d2f-4155-42a9-bc4d-7f4b955cd3fa")) {                    Plotly.newPlot(                        "43084d2f-4155-42a9-bc4d-7f4b955cd3fa",                        [{"customdata":[[0.58],[3.44],[3.9]],"hovertemplate":"lat=%{lat}\u003cbr\u003elon=%{lon}\u003cbr\u003edistance=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[42.57486611215926,42.61076526833604,42.577122030748605],"legendgroup":"","lon":[-8.803322625796476,-8.800243227573828,-8.852074287111531],"marker":{"color":[0.58,3.44,3.9],"coloraxis":"coloraxis"},"mode":"markers","name":"","showlegend":false,"subplot":"mapbox","type":"scattermapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar ...

# %% [markdown]
# **get station and sample sd speed mean hour before**

# %%
station = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Coron/station_data/coron.csv", usecols = ["time","spd_o"],parse_dates=["time"]).set_index("time")
print("raw data\n",station.head(24))

#show duplicated
df_duplicate = station[station.index.duplicated()]
print("duplicated")
print(df_duplicate)

#delete duplicated and resample
station = station[~station.index.duplicated(keep='first')]
station = station[station>0]
station = station.resample("H",label="right",closed="right").mean()

print("spd hour before")
print(station.head(4))
print("Variable statistics")
print(station.describe())
# Out:
# raw data
#                          spd_o
# time
# 2018-01-01 00:10:00  4.805559
# 2018-01-01 00:20:00  4.583337
# 2018-01-01 00:30:00  4.694448
# 2018-01-01 00:40:00  4.750004
# 2018-01-01 00:50:00  5.000004
# 2018-01-01 01:00:00  5.611116
# 2018-01-01 01:10:00  5.861116
# 2018-01-01 01:20:00  5.694449
# 2018-01-01 01:30:00  5.944449
# 2018-01-01 01:40:00  6.027783
# 2018-01-01 01:50:00  5.722227
# 2018-01-01 02:00:00  5.527782
# 2018-01-01 02:10:00  6.611116
# 2018-01-01 02:20:00  5.944449
# 2018-01-01 02:30:00  6.250005
# 2018-01-01 02:40:00  6.527783
# 2018-01-01 02:50:00  5.055560
# 2018-01-01 03:00:00  5.055560
# 2018-01-01 03:10:00  5.305560
# 2018-01-01 03:20:00  5.777782
# 2018-01-01 03:30:00  7.305561
# 2018-01-01 03:40:00  8.138895
# 2018-01-01 03:50:00  7.083339
# 2018-01-01 04:00:00  6.361116
# duplicated
#                         spd_o
# time
# 2018-03-25 03:00:00  1.722224
# 2018-03-25 03:10:00  4.833337
# 2018-03-25 03:20:00  4.916671
# 2018-03-25 03:30:00  4.638893
# 2018-03-25 03:40:00  4.416670
# 2018-03-25 03:50:00  3.583336
# 2019-03-31 03:00:00  4.333337
# 2019-03-31 03:10:00  6.750005
# 2019-03-31 03:20:00  6.222227
# 2019-03-31 03:30:00  3.583336
# 2019-03-31 03:40:00  4.777782
# 2019-03-31 03:50:00  6.555561
# 2020-03-29 03:00:00  8.527785
# 2020-03-29 03:10:00  8.527785
# 2020-03-29 03:20:00  4.611115
# 2020-03-29 03:30:00  4.638893
# 2020-03-29 03:40:00  4.222226
# 2020-03-29 03:50:00  3.500003
# 2021-03-28 03:00:00  2.972225
# 2021-03-28 03:10:00  2.388891
# 2021-03-28 03:20:00  2.500002
# 2021-03-28 03:30:00  1.777779
# 2021-03-28 03:40:00  1.555557
# 2021-03-28 03:50:00  1.527779
# 2022-03-27 03:00:00  2.444446
# 2022-03-27 03:10:00  1.750001
# 2022-03-27 03:20:00  2.027779
# 2022-03-27 03:30:00  1.888890
# 2022-03-27 03:40:00  1.638890
# 2022-03-27 03:50:00  2.277780
# spd hour before
#                         spd_o
# time
# 2018-01-01 01:00:00  4.907411
# 2018-01-01 02:00:00  5.796301
# 2018-01-01 03:00:00  5.907412
# 2018-01-01 04:00:00  6.662042
# Variable statistics
#               spd_o
# count  43108.000000
# mean       4.674167
# std        3.060638
# min        0.027778
# 25%        2.064816
# 50%        4.231485
# 75%        6.870376
# max       17.694459

# %% [markdown]
# **get meteorologic model d0**

# %%
#ria forecast d0
met_model = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Coron/met_ model/lat42.58lon-8.8046p3R4KmD0.csv",parse_dates=["time"]).drop(columns=["Unnamed: 0"]).set_index("time")
met_model.drop_duplicates().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 42021 entries, 2018-01-01 01:00:00 to 2023-01-01 23:00:00
# Data columns (total 75 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   dir0         42021 non-null  float64
#  1   snow_prec0   42021 non-null  float64
#  2   snowlevel0   42021 non-null  float64
#  3   mod0         42021 non-null  float64
#  4   wind_gust0   42021 non-null  float64
#  5   mslp0        42021 non-null  float64
#  6   temp0        42021 non-null  float64
#  7   rh0          42021 non-null  float64
#  8   visibility0  42021 non-null  float64
#  9   lhflx0       42021 non-null  float64
#  10  lwflx0       42021 non-null  float64
#  11  conv_prec0   42021 non-null  float64
#  12  prec0        42021 non-null  float64
#  13  swflx0       42021 non-null  float64
#  14  shflx0       42021 non-null  float64
#  15  cape0        42021 non-null  float64
#  16  cin0         42021 non-null  float64
#  17  cfh0         42021 non-null  float64
#  18  cfl0         42021 non-null  float64
#  19  cfm0         42021 non-null  float64
#  20  cft0         42021 non-null  float64
#  21  HGT5000      42021 non-null  float64
#  22  HGT8500      42021 non-null  float64
#  23  T5000        42021 non-null  float64
#  24  T8500        42021 non-null  float64
#  25  dir1         42021 non-null  float64
#  26  snow_prec1   42021 non-null  float64
#  27  snowlevel1   42021 non-null  float64
#  28  mod1         42021 non-null  float64
#  29  wind_gust1   42021 non-null  float64
#  30  mslp1        42021 non-null  float64
#  31  temp1        42021 non-null  float64
#  32  rh1          42021 non-null  float64
#  33  visibility1  42021 non-null  float64
#  34  lhflx1       42021 non-null  float64
#  35  lwflx1       42021 non-null  float64
#  36  conv_prec1   42021 non-null  float64
#  37  prec1        42021 non-null  float64
#  38  swflx1       42021 non-null  float64
#  39  shflx1       42021 non-null  float64
#  40  cape1        42021 non-null  float64
#  41  cin1         42021 non-null  float64
#  42  cfh1         42021 non-null  float64
#  43  cfl1         42021 non-null  float64
#  44  cfm1         42021 non-null  float64
#  45  cft1         42021 non-null  float64
#  46  HGT5001      42021 non-null  float64
#  47  HGT8501      42021 non-null  float64
#  48  T5001        42021 non-null  float64
#  49  T8501        42021 non-null  float64
#  50  dir2         42021 non-null  float64
#  51  snow_prec2   42021 non-null  float64
#  52  snowlevel2   42021 non-null  float64
#  53  mod2         42021 non-null  float64
#  54  wind_gust2   42021 non-null  float64
#  55  mslp2        42021 non-null  float64
#  56  temp2        42021 non-null  float64
#  57  rh2          42021 non-null  float64
#  58  visibility2  42021 non-null  float64
#  59  lhflx2       42021 non-null  float64
#  60  lwflx2       42021 non-null  float64
#  63  prec2        41314 non-null  float64
#  64  swflx2       41314 non-null  float64
#  65  shflx2       41314 non-null  float64
#  66  cape2        41314 non-null  float64
#  67  cin2         41314 non-null  float64
#  68  cfh2         41314 non-null  float64
#  69  cfl2         41314 non-null  float64
#  70  cfm2         41314 non-null  float64
#  71  cft2         41314 non-null  float64
#  72  HGT5002      41314 non-null  float64
#  73  HGT8502      41314 non-null  float64
#  74  T5002        41314 non-null  float64
#  75  T8502        41314 non-null  float64
# dtypes: float64(76)
# memory usage: 24.3 MB

# %% [markdown]
# **LGBMRegressor**

# %%
from lightgbm.sklearn import LGBMRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

#numpy randomseed
np.random.seed(1)

# target variable
Y = df_all.spd_o
X = df_all[df_all.columns[1:]]

MAE = []
for t in range (0,10):
  X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.1, )
  ml_model = LGBMRegressor(n_estimators=200).fit(X_train,y_train)
  y_pred = ml_model.predict(X_test)
  MAE.append(round(mean_absolute_error(y_test,y_pred),2))
  print("machine learning number:",t)
  df = pd.DataFrame({"y_test":y_test},index=y_test.index)
  df["y_pred"] = y_pred
  df["diff"] = df["y_pred"]-df["y_test"]
  print(df.describe())
print("\nDifferences last machine learning model")
fig = px.line(df["diff"].sort_index())
fig.show()
print("Mean absolute value all machine learning models")
df_r=pd.DataFrame({"MAE":MAE,});
df_r.describe()
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.090579 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18216
# [LightGBM] [Info] Number of data points in the train set: 37182, number of used features: 72
# [LightGBM] [Info] Start training from score 4.676378
# machine learning number: 0
#             y_test       y_pred         diff
# count  4132.000000  4132.000000  4132.000000
# mean      4.732683     4.674315    -0.058367
# std       3.076670     2.638878     1.475024
# min       0.027778     0.631249   -11.084057
# 25%       2.125002     2.403632    -0.914276
# 50%       4.310189     4.241682     0.002022
# 75%       6.959496     6.545584     0.820808
# max      16.060198    14.870964     7.382477
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037018 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18217
# [LightGBM] [Info] Number of data points in the train set: 37182, number of used features: 72
# [LightGBM] [Info] Start training from score 4.683062
# machine learning number: 1
#             y_test       y_pred         diff
# count  4132.000000  4132.000000  4132.000000
# mean      4.672537     4.644753    -0.027784
# std       3.059998     2.618914     1.512532
# min       0.027778     0.351656   -10.255913
# 25%       2.083335     2.387791    -0.928980
# 50%       4.215281     4.159268     0.019530
# 75%       6.857644     6.473256     0.820857
# max      16.060198    14.141813     9.397942
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.057162 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18209
# [LightGBM] [Info] Number of data points in the train set: 37182, number of used features: 72
# [LightGBM] [Info] Start training from score 4.678960
# machine learning number: 2
#             y_test       y_pred         diff
# count  4132.000000  4132.000000  4132.000000
# mean      4.709454     4.716110     0.006656
# std       3.070692     2.644275     1.472031
# min       0.055556     0.458543    -9.939294
# 25%       2.060187     2.396621    -0.881122
# 50%       4.266207     4.279497     0.043020
# 75%       6.976857     6.611717     0.886040
# max      16.060198    12.933950     5.976844
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035590 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18204
# [LightGBM] [Info] Number of data points in the train set: 37182, number of used features: 72
# [LightGBM] [Info] Start training from score 4.684031
# machine learning number: 3
#             y_test       y_pred         diff
# count  4132.000000  4132.000000  4132.000000
# mean      4.663825     4.675910     0.012085
# std       3.066160     2.672238     1.492609
# min       0.055556     0.315838    -9.323194
# 25%       2.045141     2.331408    -0.863436
# 50%       4.219911     4.231673     0.049212
# 75%       6.820607     6.567665     0.861159
# max      17.046310    14.580355     9.429972
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.045640 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18210
# [LightGBM] [Info] Number of data points in the train set: 37182, number of used features: 72
# [LightGBM] [Info] Start training from score 4.673801
# machine learning number: 4
#             y_test       y_pred         diff
# count  4132.000000  4132.000000  4132.000000
# mean      4.755877     4.742146    -0.013731
# std       3.085066     2.670222     1.478443
# min       0.027778     0.792466    -7.505289
# 25%       2.096066     2.462062    -0.848169
# 50%       4.310189     4.323914     0.026612
# 75%       6.995376     6.657100     0.848978
# max      16.101865    13.078051     6.261058
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.061401 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18215
# [LightGBM] [Info] Number of data points in the train set: 37182, number of used features: 72
# [LightGBM] [Info] Start training from score 4.676520
# machine learning number: 5
#             y_test       y_pred         diff
# count  4132.000000  4132.000000  4132.000000
# mean      4.731411     4.753502     0.022091
# std       3.070865     2.649629     1.490049
# min       0.055556     0.010111    -9.572627
# 25%       2.162039     2.479928    -0.843296
# 50%       4.324078     4.322788     0.055419
# 75%       7.000006     6.662675     0.894020
# max      17.046310    14.313385     6.699814
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037486 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18217
# [LightGBM] [Info] Number of data points in the train set: 37182, number of used features: 72
# [LightGBM] [Info] Start training from score 4.678626
# machine learning number: 6
#             y_test       y_pred         diff
# count  4132.000000  4132.000000  4132.000000
# mean      4
-28T01:00:00","2018-01-28T08:00:00","2018-01-28T12:00:00","2018-01-29T20:00:00","2018-01-29T21:00:00","2018-01-30T15:00:00","2018-01-31T17:00:00","2018-02-02T16:00:00","2018-02-02T19:00:00","2018-02-03T16:00:00","2018-02-03T19:00:00","2018-02-04T10:00:00","2018-02-05T19:00:00","2018-02-05T20:00:00","2018-02-05T21:00:00","2018-02-05T22:00:00","2018-02-06T14:00:00","2018-02-06T15:00:00","2018-02-06T17:00:00","2018-02-07T17:00:00","2018-02-08T17:00:00","2018-02-08T18:00:00","2018-02-09T15:00:00","2018-02-09T17:00:00","2018-02-09T19:00:00","2018-02-09T22:00:00","2018-02-10T07:00:00","2018-02-10T12:00:00","2018-02-10T20:00:00","2018-02-11T07:00:00","2018-02-11T17:00:00","2018-02-11T20:00:00","2018-02-12T01:00:00","2018-02-13T09:00:00","2018-02-13T10:00:00","2018-02-13T23:00:00","2018-02-14T02:00:00","2018-02-14T10:00:00","2018-02-14T16:00:00","2018-02-14T19:00:00","2018-02-14T23:00:00","2018-02-15T13:00:00","2018-02-16T01:00:00","2018-02-16T06:00:00","2018-02-16T12:00:00","2018-02-16T14:00:00","2018-02-17T10:00:00","2018-02-18T02:00:00","2018-02-18T09:00:00","2018-02-18T15:00:00","2018-02-19T08:00:00","2018-02-19T14:00:00","2018-02-19T22:00:00","2018-02-20T06:00:00","2018-02-20T11:00:00","2018-02-20T16:00:00","2018-02-20T20:00:00","2018-02-21T02:00:00","2018-02-21T17:00:00","2018-02-21T23:00:00","2018-02-23T14:00:00","2018-02-23T17:00:00","2018-02-24T09:00:00","2018-02-24T15:00:00","2018-02-24T20:00:00","2018-02-27T05:00:00","2018-02-27T08:00:00","2018-02-27T11:00:00","2018-02-28T01:00:00","2018-02-28T07:00:00","2018-02-28T10:00:00","2018-02-28T16:00:00","2018-03-01T09:00:00","2018-03-01T11:00:00","2018-03-01T15:00:00","2018-03-01T17:00:00","2018-03-02T05:00:00","2018-03-02T14:00:00","2018-03-02T17:00:00","2018-03-02T22:00:00","2018-03-03T08:00:00","201 ...
# Mean absolute value all machine learning models
#              MAE
# count  10.000000
# mean    1.112000
# std     0.016865
# min     1.080000
# 25%     1.110000
# 50%     1.115000
# 75%     1.120000
# max     1.140000

# %% [markdown]
# **Shapiro test normality MAE samples tested**

# %%
from scipy.stats import shapiro

sta, p = shapiro(MAE)
print("\np value:",p)
print("significance level alpha=0.01")

alpha = 0.01
if p>alpha:
  print("Accept null hypothesis: normal distribution variable MAE in the samples")
else:
  print("Reject null Hypothesis. Alternative hypothesis variable MAE no normal distribution in samples")
# Out:
# p value: 0.23281915485858917
# significance level alpha=0.01
# Accept null hypothesis: normal distribution variable MAE in the samples

# %% [markdown]
# **Add time variables**

# %%
df_all["hour"] = df_all.index.hour
df_all["month"] = df_all.index.month
df_all["dayofyear"] = df_all.index.dayofyear
df_all["weekofyear"] = df_all.index.isocalendar().week.astype(int)

#numpy randomseed
np.random.seed(1)

# target variable
Y = df_all.spd_o
X = df_all[df_all.columns[1:]]


MAE_t = []
for t in range (0,10):
  X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.1, )
  ml_model = LGBMRegressor(n_estimators=200).fit(X_train,y_train)
  y_pred = ml_model.predict(X_test)
  MAE_t.append(round(mean_absolute_error(y_test,y_pred),2))
  print("machine learning number:",t)
  df = pd.DataFrame({"y_test":y_test},index=y_test.index)
  df["y_pred"] = y_pred
  df["diff"] = df["y_pred"]-df["y_test"]
  print(df.describe())
print("\nDifferences last machine learning model")
fig = px.line(df["diff"].sort_index())
fig.show()
print("Mean absolute value all machine learning models")
df_r=pd.DataFrame({"MAE_t":MAE_t,});
df_r.describe()
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.042755 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18556
# [LightGBM] [Info] Number of data points in the train set: 37182, number of used features: 76
# [LightGBM] [Info] Start training from score 4.676378
# machine learning number: 0
#             y_test       y_pred         diff
# count  4132.000000  4132.000000  4132.000000
# mean      4.732683     4.676195    -0.056487
# std       3.076670     2.660084     1.400833
# min       0.027778     0.539150   -10.334622
# 25%       2.125002     2.401549    -0.861159
# 50%       4.310189     4.249326    -0.011584
# 75%       6.959496     6.550463     0.781656
# max      16.060198    14.804679     7.295004
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.066612 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18557
# [LightGBM] [Info] Number of data points in the train set: 37182, number of used features: 76
# [LightGBM] [Info] Start training from score 4.683062
# machine learning number: 1
#             y_test       y_pred         diff
# count  4132.000000  4132.000000  4132.000000
# mean      4.672537     4.653573    -0.018964
# std       3.059998     2.633185     1.465551
# min       0.027778     0.135660    -9.334680
# 25%       2.083335     2.394551    -0.869857
# 50%       4.215281     4.202649    -0.029685
# 75%       6.857644     6.522522     0.800143
# max      16.060198    14.050630     9.156094
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037344 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18550
# [LightGBM] [Info] Number of data points in the train set: 37182, number of used features: 76
# [LightGBM] [Info] Start training from score 4.678960
# machine learning number: 2
#             y_test       y_pred         diff
# count  4132.000000  4132.000000  4132.000000
# mean      4.709454     4.722398     0.012944
# std       3.070692     2.671374     1.411323
# min       0.055556     0.324190    -9.512006
# 25%       2.060187     2.384910    -0.802925
# 50%       4.266207     4.320265     0.032078
# 75%       6.976857     6.639208     0.844472
# max      16.060198    12.985297     6.934316
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.040204 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18543
# [LightGBM] [Info] Number of data points in the train set: 37182, number of used features: 76
# [LightGBM] [Info] Start training from score 4.684031
# machine learning number: 3
#             y_test       y_pred         diff
# count  4132.000000  4132.000000  4132.000000
# mean      4.663825     4.671502     0.007677
# std       3.066160     2.690954     1.434754
# min       0.055556    -0.117545    -8.617819
# 25%       2.045141     2.347108    -0.824365
# 50%       4.219911     4.230936     0.037619
# 75%       6.820607     6.603161     0.812760
# max      17.046310    14.556288     8.393416
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.065745 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18551
# [LightGBM] [Info] Number of data points in the train set: 37182, number of used features: 76
# [LightGBM] [Info] Start training from score 4.673801
# machine learning number: 4
#             y_test       y_pred         diff
# count  4132.000000  4132.000000  4132.000000
# mean      4.755877     4.746122    -0.009756
# std       3.085066     2.680368     1.421495
# min       0.027778     0.497983    -7.473954
# 25%       2.096066     2.487437    -0.831931
# 50%       4.310189     4.329888     0.016966
# 75%       6.995376     6.637037     0.802250
# max      16.101865    12.917086     5.724926
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038329 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18557
# [LightGBM] [Info] Number of data points in the train set: 37182, number of used features: 76
# [LightGBM] [Info] Start training from score 4.676520
# machine learning number: 5
#             y_test       y_pred         diff
# count  4132.000000  4132.000000  4132.000000
# mean      4.731411     4.754817     0.023406
# std       3.070865     2.672403     1.440400
# min       0.055556     0.427121    -9.074646
# 25%       2.162039     2.457540    -0.821146
# 50%       4.324078     4.307391     0.041947
# 75%       7.000006     6.735773     0.863184
# max      17.046310    15.340606     6.433330
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036862 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18555
# [LightGBM] [Info] Number of data points in the train set: 37182, number of used features: 76
# [LightGBM] [Info] Start training from score 4.678626
# machine learning number: 6
#             y_test       y_pred         diff
# count  4132.000000  4132.000000  4132.000000
# mean      4.712462     4.676920    -0.035542
# std       3.051623     2.655076     1.387273
# min       0.027778     0.448839   -10.002289
# 25%       2.106483     2.405950    -0.841356
# 50%       4.307874     4.225769     0.008652
# 75%       6.863431     6.543656     0.773307
# max      15.537049    14.205539     6.717263
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.058824 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18557
# [LightGBM] [Info] Number of data points in the train set: 37182, number of used features: 76
# [LightGBM] [Info] Start training from score 4.687081
# machine learning number: 7
#             y_test       y_pred         diff
# count  4132.000000  4132.000000  4132.000000
# mean      4.636374     4.678832     0.042458
# std       3.072961     2.686801     1.385490
# min       0.055556     0.391029    -5.979639
# 25%       2.000002     2.369491    -0.769814
# 50%       4.180559     4.182881     0.048603
# 75%       6.857644     6.585113     0.854592
# max      14.486123    14.211936     7.647082
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038061 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 18557
# [LightGBM] [Info] Number of data points in the train set: 37182, number of used features: 76
# [LightGBM] [Info] Start training from score 4.681335
# machine learning number: 8
#             y_test       y_pred         diff
# count  4132.000000  4132.000000  4132.000000
# mean      4.688085     4.721371     0.033286
# std       3.051015     2.660092     1.426785
# min       0.027778     0.175350    -7.071671
# 25%       2.077548     2.423068    -0.780848
# 50%       4.233800     4.257126     0.059789
# 75%       6.917830     6.655283     0.855758
# max      15.393531    13.304070    10.069416
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.
00:00","2018-02-10T12:00:00","2018-02-10T20:00:00","2018-02-11T07:00:00","2018-02-11T17:00:00","2018-02-11T20:00:00","2018-02-12T01:00:00","2018-02-13T09:00:00","2018-02-13T10:00:00","2018-02-13T23:00:00","2018-02-14T02:00:00","2018-02-14T10:00:00","2018-02-14T16:00:00","2018-02-14T19:00:00","2018-02-14T23:00:00","2018-02-15T13:00:00","2018-02-16T01:00:00","2018-02-16T06:00:00","2018-02-16T12:00:00","2018-02-16T14:00:00","2018-02-17T10:00:00","2018-02-18T02:00:00","2018-02-18T09:00:00","2018-02-18T15:00:00","2018-02-19T08:00:00","2018-02-19T14:00:00","2018-02-19T22:00:00","2018-02-20T06:00:00","2018-02-20T11:00:00","2018-02-20T16:00:00","2018-02-20T20:00:00","2018-02-21T02:00:00","2018-02-21T17:00:00","2018-02-21T23:00:00","2018-02-23T14:00:00","2018-02-23T17:00:00","2018-02-24T09:00:00","2018-02-24T15:00:00","2018-02-24T20:00:00","2018-02-27T05:00:00","2018-02-27T08:00:00","2018-02-27T11:00:00","2018-02-28T01:00:00","2018-02-28T07:00:00","2018-02-28T10:00:00","2018-02-28T16:00:00","2018-03-01T09:00:00","2018-03-01T11:00:00","2018-03-01T15:00:00","2018-03-01T17:00:00","2018-03-02T05:00:00","2018-03-02T14:00:00","2018-03-02T17:00:00","2018-03-02T22:00:00","2018-03-03T08:00:00","201 ...
# Mean absolute value all machine learning models
#            MAE_t
# count  10.000000
# mean    1.070000
# std     0.017638
# min     1.040000
# 25%     1.062500
# 50%     1.070000
# 75%     1.077500
# max     1.100000

# %% [markdown]
# **T test two related samples. This is a test for the null hypothesis that two related samples have identical mean absolute error. Alternative hypothesis the  mean absolute error from the sample with time variables is less than the mean absolute error of from the sample with time variables. Significance level (alpha) = 0.01**

# %%
from scipy import stats

alpha = 0.01
sta, p_value = stats.ttest_rel(MAE, MAE_t, alternative="greater")

print("\nMAE without time variables:", np.round(MAE,3))
print("\nMAE with time variables:", np.round(MAE_t,3))
print("\nalpha: ",alpha)
print("\np_value point: ",p_value)

if p_value < alpha:
    print("\nwe are rejecting null hypothesis  H0: MAE machine learning without time variables = MAE machine learning with time variables")
    print("\nwe are accepting alternative hypothesis: the MAE of the sample with time variables inputs is less than MAE of the sample without time variables inputs")
else:
    print("\nwe are accepting null hypothesis:  H0: MAE machine learning without time variables = MAE machine learning with time variables")
# Out:
# MAE without time variables: [1.11 1.14 1.11 1.12 1.11 1.12 1.09 1.08 1.12 1.12]
#
# MAE with time variables: [1.06 1.1  1.07 1.07 1.07 1.09 1.05 1.04 1.07 1.08]
#
# alpha:  0.01
#
# p_value point:  2.950997029766481e-09
#
# we are rejecting null hypothesis  H0: MAE machine learning without time variables = MAE machine learning with time variables
#
# we are accepting alternative hypothesis: the MAE of the sample with time variables inputs is less than MAE of the sample without time variables inputs

# %% [markdown]
# **Save algorithm**

# %%
import pickle
from sklearn.pipeline import Pipeline


estimators = [('ml_model', ml_model)]
pipe = Pipeline(estimators)
print(pipe)
al_file={"x_var":X.columns,"coor":coor,"pipe":pipe}
pickle.dump(al_file, open("/content/drive/MyDrive/Colab Notebooks/Coron/algorithms/rspd_coron_d0.al", 'wb'))
# Out:
# Pipeline(steps=[('ml_model', LGBMRegressor(n_estimators=200))])
